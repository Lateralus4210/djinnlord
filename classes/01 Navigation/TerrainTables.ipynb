# %%
class TerrainTables:
    def check():
        location_info = Map.get_object_at_coordinate(CharacterLocation.position_current[0], CharacterLocation.position_current[1])
        
        if location_info and 'terrain' in location_info:
            if location_info['terrain'] == "A":
                LocationFrame.terrain_current_label.configure(text="Airy Plains")
                
            if location_info['terrain'] == "B":
                LocationFrame.terrain_current_label.configure(text="Sandy Beach")

            if location_info['terrain'] == "C":
                LocationFrame.terrain_current_label.configure(text="Cursed Dunes")

            if location_info['terrain'] == "D":
                LocationFrame.terrain_current_label.configure(text="Desert Storm")

            if location_info['terrain'] == "E":
                LocationFrame.terrain_current_label.configure(text="Eroded Hills")

            if location_info['terrain'] == "F":
                LocationFrame.terrain_current_label.configure(text="Frosted Tips")

            if location_info['terrain'] == "G":
                LocationFrame.terrain_current_label.configure(text="Overgrown Jungle")

            if location_info['terrain'] == "H":
                LocationFrame.terrain_current_label.configure(text="Mountain Heights")

            if location_info['terrain'] == "I":
                LocationFrame.terrain_current_label.configure(text="Cliffside")

            if location_info['terrain'] == "J":
                LocationFrame.terrain_current_label.configure(text="Jagged Crevasse")

            if location_info['terrain'] == "K":
                LocationFrame.terrain_current_label.configure(text="Lightning Hotpot")

            if location_info['terrain'] == "L":
                LocationFrame.terrain_current_label.configure(text="Landless Depths")            
            
            if location_info['terrain'] == "M":
                LocationFrame.terrain_current_label.configure(text="Wet Meadows")
                
            if location_info['terrain'] == "N":
                LocationFrame.terrain_current_label.configure(text="Forested Nadir")
                
            if location_info['terrain'] == "O":
                LocationFrame.terrain_current_label.configure(text="Open Ocean")

            if location_info['terrain'] == "P":
                LocationFrame.terrain_current_label.configure(text="Pumice Rock")

            if location_info['terrain'] == "Q":
                LocationFrame.terrain_current_label.configure(text="Quiet Woods")

            if location_info['terrain'] == "R":
                LocationFrame.terrain_current_label.configure(text="Rocky Beach")

            if location_info['terrain'] == "S":
                LocationFrame.terrain_current_label.configure(text="Scorched Humus")

            if location_info['terrain'] == "T":
                LocationFrame.terrain_current_label.configure(text="Forested Tundra")

            if location_info['terrain'] == "V":
                LocationFrame.terrain_current_label.configure(text="Vocanic Gulley")

            if location_info['terrain'] == "W":
                LocationFrame.terrain_current_label.configure(text="Water's Edge")
        
        else:
            # Handle the case where terrain_info is None or does not contain 'terrain'
            print("Terrain information not found or invalid.")

# %%
print("TerrainTables class loaded.")
