# %%
class Enemy:
    name = ""
    health_max = 0
    health_current = 0 
    attack_one = ""
    attack_two = ""
    attack_one_damage = 0
    attack_two_damage = 0
    accuracy = 70

    def create_enemy(enemy_name):
        Enemy.name = enemy_name
        
        if enemy_name == "butterfly":
            Enemy.health_max = 4
            Enemy.attack_one = "scratch"
            Enemy.attack_two = "scratch"

        elif enemy_name == "chicken":
            Enemy.health_max = 14
            Enemy.attack_one = "scratch"
            Enemy.attack_two = "scratch"
    
        elif enemy_name == "giant rat":
            Enemy.health_max = 20
            Enemy.attack_one = "scratch"
            Enemy.attack_two = "scratch"
    
        elif enemy_name == "garden snake":
            Enemy.health_max = 28
            Enemy.attack_one = "scratch"
            Enemy.attack_two = "scratch"
    
        elif enemy_name == "harpy chick":
            Enemy.health_max = 35
            Enemy.attack_one = "scratch"
            Enemy.attack_two = "scratch"
    
        elif enemy_name == "bee swarm":
            Enemy.health_max = 40
            Enemy.attack_one = "scratch"
            Enemy.attack_two = "scratch"
        
        elif enemy_name == "boar":
            Enemy.health_max = 45
            Enemy.attack_one = "scratch"
            Enemy.attack_two = "scratch"
        
        elif enemy_name == "wolf":
            Enemy.health_max = 50
            Enemy.attack_one = "scratch"
            Enemy.attack_two = "scratch"
        
        elif enemy_name == "syren":
            Enemy.health_max = 50
            Enemy.attack_one = "scratch"
            Enemy.attack_two = "scratch"
        
        elif enemy_name == "zombie":
            Enemy.health_max = 80
            Enemy.attack_one = "scratch"
            Enemy.attack_two = "scratch"
        
        else:
            raise ValueError(f"Unknown enemy type: {enemy_name}")

        print("Enemy " + enemy_name + " created.")
        Enemy.health_current = Enemy.health_max
        print("Enemy health set to " + str(Enemy.health_current) + " out of " + str(Enemy.health_max))
        CharacterProfile.in_battle = True
        CommandsFrame.entry_listbox.insert(0, "    !! A " + Enemy.name + " appeared!")
        EnemyFrame.enemy_name_label.config(text=str.title((Enemy.name)))
        EnemyFrame.enemy_health_current_label.config(text=str(Enemy.health_current) + " / " + str(Enemy.health_max) + " HP")

        if 1 <= CharacterSkills.level_current <= 10:
            Enemy.attack_one_damage = 1 * CharacterSkills.level_current
            Enemy.attack_two_damage = 2 * CharacterSkills.level_current

    def enemy_attack_turn():
        
        if Enemy.health_current >= 0:
            EnemyAttack.go()
            #update_enemy_health_progressbar
    
        else:
            Enemy.health_current = 0
            #update_enemy_health_progressbar
            battle_success()
    
    # def determine_enemy_attack():
# Out:
# Custom class: Enemy successfully loaded.

# %%
print("Custom class: Enemy successfully loaded.")
