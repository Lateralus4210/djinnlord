# %%
class EnemyDropTables:
    def check():
        random_item_number = random.randint(1, 100)

        print("Random item #" + str(random_item_number))
        debug_listbox.insert(0, "Random item #" + str(random_item_number))
                          
        selected_item_slot = None
        
        item_ranges = {
            1: (1, 30),
            2: (31, 60),
            3: (61, 90),
            4: (91, 100)
        }
    
        for item_range, (min_range, max_range) in item_ranges.items():
            if min_range <= random_item_number <= max_range:
                selected_item_slot = item_range
                break

        debug_listbox.insert(0, "Item slot #" + str(selected_item_slot))

        enemy_name = Enemy.name
    
        if enemy_name == "butterfly":
            if selected_item_slot == 1:
                Item.give("Butterfly Wing")
            if selected_item_slot == 2:
                Item.give("Cocoon")
            if selected_item_slot == 3:
                Item.give("Butterfly Wing")
            if selected_item_slot == 4:
                Item.give("Butterfly Antenna")

        elif enemy_name == "chicken":
            if selected_item_slot == 1:
                Item.give("Plant Material")
            if selected_item_slot == 2:
                Item.give("Plant Material")
            if selected_item_slot == 3:
                Item.give("Plant Material")
            if selected_item_slot == 4:
                Item.give("Plant Material")
    
        elif enemy_name == "giant rat":
            if selected_item_slot == 1:
                Item.give("Plant Material")
            if selected_item_slot == 2:
                Item.give("Plant Material")
            if selected_item_slot == 3:
                Item.give("Plant Material")
            if selected_item_slot == 4:
                Item.give("Plant Material")
    
        elif enemy_name == "garden snake":
            if selected_item_slot == 1:
                Item.give("Plant Material")
            if selected_item_slot == 2:
                Item.give("Plant Material")
            if selected_item_slot == 3:
                Item.give("Plant Material")
            if selected_item_slot == 4:
                Item.give("Plant Material")

        elif enemy_name == "harpy chick":
            if selected_item_slot == 1:
                Item.give("Plant Material")
            if selected_item_slot == 2:
                Item.give("Plant Material")
            if selected_item_slot == 3:
                Item.give("Plant Material")
            if selected_item_slot == 4:
                Item.give("Plant Material")
    
        elif enemy_name == "bee swarm":
            if selected_item_slot == 1:
                Item.give("Plant Material")
            if selected_item_slot == 2:
                Item.give("Plant Material")
            if selected_item_slot == 3:
                Item.give("Plant Material")
            if selected_item_slot == 4:
                Item.give("Plant Material")
        
        elif enemy_name == "boar":
            if selected_item_slot == 1:
                Item.give("Plant Material")
            if selected_item_slot == 2:
                Item.give("Plant Material")
            if selected_item_slot == 3:
                Item.give("Plant Material")
            if selected_item_slot == 4:
                Item.give("Plant Material")
        
        elif enemy_name == "wolf":
            if selected_item_slot == 1:
                Item.give("Plant Material")
            if selected_item_slot == 2:
                Item.give("Plant Material")
            if selected_item_slot == 3:
                Item.give("Plant Material")
            if selected_item_slot == 4:
                Item.give("Plant Material")
        
        elif enemy_name == "syren":
            if selected_item_slot == 1:
                Item.give("Plant Material")
            if selected_item_slot == 2:
                Item.give("Plant Material")
            if selected_item_slot == 3:
                Item.give("Plant Material")
            if selected_item_slot == 4:
                Item.give("Plant Material")
        
        elif enemy_name == "zombie":
            if selected_item_slot == 1:
                Item.give("Plant Material")
            if selected_item_slot == 2:
                Item.give("Plant Material")
            if selected_item_slot == 3:
                Item.give("Plant Material")
            if selected_item_slot == 4:
                Item.give("Plant Material")

        Inventory.inv['Plant Material'] += 1

# %%
print("EnemyDropTables class loaded.")
