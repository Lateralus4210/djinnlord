# %%
class SpellsAbilitiesFrame:
    screen_height = root.winfo_screenheight()
    screen_width = root.winfo_screenwidth()
    one_third_screen_width = screen_width // 3
    one_third_screen_height = screen_height // 3
    
    spells_abilities_frame = tk.Frame(root, borderwidth=0, relief="flat", padx=0, pady=0, bg=Palettes.panel_two_color) # Licorice

    
    spells_abilities_frame.place (x=0,
              y=2* one_third_screen_height,
              width = one_third_screen_width - InterfaceStyleConfig.margin_pixel_amount,
              height = one_third_screen_height - InterfaceStyleConfig.margin_pixel_amount)
    



    spells_abilities_label = tk.Label(spells_abilities_frame, text="Spells & Abilities")
    spells_abilities_label.pack()

    InterfaceStyleConfig.title_labels.append(spells_abilities_label)
    InterfaceStyleConfig.panel_two_labels.append(spells_abilities_label)

    ###############################################################

    spells_frame = tk.Frame(spells_abilities_frame, height=80, width=400, pady=20, bg = Palettes.panel_two_color)
    spells_frame.pack()
    
    air_spell_label = tk.Label(spells_frame, 
                                  text="1. Puff of Wind")
    InterfaceStyleConfig.panel_two_labels.append(air_spell_label)
    air_spell_label.pack()
    
    water_spell_label = tk.Label(spells_frame, 
                                  text="1. Puff of Wind")
    InterfaceStyleConfig.panel_two_labels.append(water_spell_label)
    #water_spell_label.pack()
    
    ground_spell_label = tk.Label(spells_frame, 
                                  text="1. Puff of Wind")
    InterfaceStyleConfig.panel_two_labels.append(ground_spell_label)
    #ground_spell_label.pack()
    
    fire_spell_label = tk.Label(spells_frame, 
                                  text="1. Puff of Wind")
    InterfaceStyleConfig.panel_two_labels.append(fire_spell_label)
    #fire_spell_label.pack()
    
    wood_spell_label = tk.Label(spells_frame, 
                                  text="1. Puff of Wind")
    InterfaceStyleConfig.panel_two_labels.append(wood_spell_label)
    #wood_spell_label.pack()
    
    electric_spell_label = tk.Label(spells_frame, 
                                  text="1. Puff of Wind")
    InterfaceStyleConfig.panel_two_labels.append(electric_spell_label)
    #electric_spell_label.pack()
    
    amoeba_spell_label = tk.Label(spells_frame, 
                                  text="1. Puff of Wind")
    InterfaceStyleConfig.panel_two_labels.append(amoeba_spell_label)
    #amoeba_spell_label.pack()
    
    time_spell_label = tk.Label(spells_frame, 
                                  text="1. Puff of Wind")
    InterfaceStyleConfig.panel_two_labels.append(time_spell_label)
    #time_spell_label.pack()

    ###############################################################    
    
    abilities_frame = tk.Frame(spells_abilities_frame, height=80, width=400, bg="black")
    abilities_frame.pack()
    
    print("Spells and abilities labels packed.")

# %%
print("SpellsAbilitiesFrame class loaded.")
