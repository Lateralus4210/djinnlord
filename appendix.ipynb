# %%
'''
# Define getter and setter methods for all attributes using a loop
def define_getter_setter(self, attribute_name):
    def getter(self):
        return getattr(self, attribute_name)

    def setter(self, value):
        setattr(self, attribute_name, value)

    getter_name = f'get_{attribute_name}'
    setter_name = f'set_{attribute_name}'

    setattr(Character, f'get_{attribute_name}', getter)
    setattr(Character, f'set_{attribute_name}', setter)
    print(f"Created getter {getter_name} and setter {setter_name} for {attribute_name}")

for attribute in Character.attributes_list:
    define_getter_setter(None, attribute)
'''

#appendix

'''ascii_map = 
 __ __ __ __ __ __ __ __ __ __ __
|__|__|__|__|__|__|__|__|__|__|__|
|__|__|__|__|__|__|__|__|__|__|__|
|__|__|__|__|__|__|__|__|__|__|__|
|__|__|__|XX|__|YY|__|__|__|__|__|
|__|__|__|__|__|__|__|__|__|__|__|
|__|__|__|__|__|__|__|__|__|__|__|
|__|__|__|__|__|__|__|__|__|__|__|

ascii_opening = 
                            ,-.                               
       ___,---.__          /'|`\          __,---,___          
    ,-'    \`    `-.____,-'  |  `-.____,-'    //    `-.       
  ,'        |           ~'\     /`~           |        `.      
 /      ___//              `. ,'          ,  , \___      \    
|    ,-'   `-.__   _         |        ,    __,-'   `-.    |    
|   /          /\_  `   .    |    ,      _/\          \   |   
\  |           \ \`-.___ \   |   / ___,-'/ /           |  /  
 \  \           | `._   `\\  |  //'   _,' |           /  /      
  `-.\         /'  _ `---'' , . ``---' _  `\         /,-'     
     ``       /     \    ,='/ \`=.    /     \       ''          
             |__   /|\_,--.,-.--,--._/|\   __|                  
             /  `./  \\`\ |  |  | /,//' \,'  \                  
            /   /     ||--+--|--+-/-|     \   \                 
           |   |     /'\_\_\ | /_/_/`\     |   |                
            \   \__, \_     `~'     _/ .__/   /            
             `-._,-'   `-._______,-'   `-._,-'
'''

"""
GUI Sample
 _________________________________________
|                1 Character              |
|-----------------------------------------| 
 ____________________ ____________________
|      2 Stats       |    3 Action        |
|--------------------|--------------------| 
 ____________________ ____________________
|    4 Command list  |     5 location     |
|--------------------|--------------------|





#def set_map_block(x, y, color):

block_size = 10

map_frame = tk.Frame(location_frame, width= 7 * block_size, height= 7 * block_size)
map_frame.pack_propagate(False)
#map_frame.pack()


block_zero_zero = tk.Label(map_frame, width = block_size, height = block_size, bg="red")
#block_zero_zero.place(x=0, y=0)
block_one_zero = tk.Frame(map_frame, width = block_size, height = block_size, bg="blue")

#block_minus_three_plus_three = tk.Label(map_frame, width = 1, height = 1, bg = "blue")
#block_minus_three_plus_three.pack(fill="none", expand=False, anchor="nw")
#block_minus_three_plus_three.grid(row=0, column=0)

map_label = tk.Label(
    location_frame,
    text="ascii_map",
    bg=panel_one_color,
    fg=panel_one_text_color,
    font=sub_title_font,
    padx=10,
    pady=10,
    borderwidth=2,
    relief="solid",
    justify="left"
)
#map_label.pack()


'''
player_position_one_north = [player_position_current[0], player_position_current[1]+1]
player_position_one_east = [player_position_current[0]+1, player_position_current[1]]
player_position_one_south = [player_position_current[0], player_position_current[1]-1]
player_position_one_west = [player_position_current[0]-1, player_position_current[1]]

player_position_two_north = [player_position_current[0], player_position_current[1]+2]
player_position_two_east = [player_position_current[0]+2, player_position_current[1]]
player_position_two_south = [player_position_current[0], player_position_current[1]-2]
player_position_two_west = [player_position_current[0]-2, player_position_current[1]]

player_position_three_north = [player_position_current[0], player_position_current[1]+3]
player_position_three_east = [player_position_current[0]+3, player_position_current[1]]
player_position_three_south = [player_position_current[0], player_position_current[1]-3]
player_position_three_west = [player_position_current[0]-3, player_position_current[1]]
'''


"""
